# %%
import pydataverse

s = pydataverse.PyDataverse(server_url="https://darus.uni-stuttgart.de")

# %%
res = s.info.get_version_info()

print(res.raw_response.json())
# Out:
# {'status': 'OK', 'data': {'version': '6.0', 'build': None}}

# %%
resp = s.access.get_datafile(file_id="196288")
print(resp.raw_response.content.decode())
# Out:
# # __Master thesis:__ From raw data to kinetic parameters: an EnzymeML-based workflow for reproducible enzyme kinetics
#
# Read the JupyterBook:
# [![Jupyter Book Badge](https://jupyterbook.org/badge.svg)](https://haeussma.github.io/masterthesis/)
#
# All data of the book is identical to data on [Dataverse of the University of Stuttgart](https://doi.org/10.18419/darus-3337)

# %%
resp = s.datasets.get_dataset(id="195575")
resp.raw_response.json()
# Out:
# {'status': 'OK',
#  'data': {'id': 195575,
#   'identifier': 'darus-3337',
#   'persistentUrl': 'https://doi.org/10.18419/darus-3337',
#   'protocol': 'doi',
#   'authority': '10.18419',
#   'publisher': 'DaRUS',
#   'publicationDate': '2023-02-02',
#   'storageIdentifier': 's3://10.18419/darus-3337',
#   'latestVersion': {'id': 3667,
#    'datasetId': 195575,
#    'datasetPersistentId': 'doi:10.18419/darus-3337',
#    'storageIdentifier': 's3://10.18419/darus-3337',
#    'versionNumber': 1,
#    'versionMinorNumber': 0,
#    'versionState': 'RELEASED',
#    'lastUpdateTime': '2023-02-02T11:09:09Z',
#    'releaseTime': '2023-02-02T11:09:09Z',
#    'createTime': '2023-01-30T15:16:51Z',
#    'publicationDate': '2023-02-02',
#    'citationDate': '2023-02-02',
#    'license': {'name': 'CC BY 4.0',
#     'uri': 'http://creativecommons.org/licenses/by/4.0',
#     'iconUri': 'https://licensebuttons.net/l/by/4.0/88x31.png'},
#    'fileAccessRequest': True,
# ...
